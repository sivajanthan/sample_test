# %%
import os
import json
import pandas as pd
import nltk
import openai
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from dotenv import load_dotenv
from typing import List, Dict, Tuple
from collections import Counter

# 📦 Setup
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')
nltk.download('punkt')
nltk.download('stopwords')

# 🎭 Allowed Emotion Categories
EMOTION_CATEGORIES = ['surprised', 'happy', 'angry', 'fearful', 'disgust', 'sad', 'neutral']
SENTIMENT_CATEGORIES = ['positive', 'negative', 'neutral']

# 😃 Emoji emotion/sentiment map (for future expansion or fallback use)
EMOJI_SENTIMENTS = {
    '😊': ('positive', 'happy'), '😁': ('positive', 'happy'), '😍': ('positive', 'happy'),
    '👍': ('positive', 'happy'), '😢': ('negative', 'sad'), '😡': ('negative', 'angry'),
    '👎': ('negative', 'disgust'), '😭': ('negative', 'sad'),
    '😱': ('neutral', 'surprised'), '😨': ('negative', 'fearful'), '😐': ('neutral', 'neutral'),
    '🚚': ('neutral', 'neutral'), '🔋': ('neutral', 'neutral'), '📞': ('neutral', 'neutral')
}

# 🔍 Extract keywords and emojis
def extract_keywords_emojis(text: str) -> Tuple[List[str], Dict[str, Tuple[str, str]]]:
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text.lower())
    keywords = [word for word in words if word.isalnum() and word not in stop_words]
    emojis = {char: EMOJI_SENTIMENTS[char] for char in text if char in EMOJI_SENTIMENTS}
    return keywords, emojis

# 🤖 GPT-based analysis
def analyze_feedback(text: str) -> Dict:
    keywords, emojis = extract_keywords_emojis(text)
    try:
        prompt = f"""
        You are an expert in customer review analysis. Analyze the following customer feedback:

        "{text}"

        Return a JSON object with EXACTLY the following keys:
        - "sentiment": one of ["positive", "negative", "neutral"]
        - "sentiment_confidence": a number from 0 to 100 representing the confidence percentage
        - "emotion": one of ["surprised", "happy", "angry", "fearful", "disgust", "sad", "neutral"]
        - "issues": a list of main issues mentioned
        - "suggested_solutions": a list of suggested actions or responses
        - "category": a high-level tag like "delivery", "support", "quality", etc.

        Ensure all fields are included even if some values are empty.
        """

        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are a helpful assistant that provides structured analysis of customer reviews."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=300
        )

        result = json.loads(response.choices[0].message.content)

    except Exception:
        # Fallback values
        result = {
            "sentiment": "neutral",
            "sentiment_confidence": 50,
            "emotion": "neutral",
            "issues": ["unspecified"],
            "suggested_solutions": ["review needed"],
            "category": "general"
        }

    return {
        "text": text,
        "sentiment": result.get("sentiment", "neutral"),
        "sentiment_confidence": result.get("sentiment_confidence", 50),
        "emotion": result.get("emotion", "neutral"),
        "issues": result.get("issues", []) or [],
        "suggested_solutions": result.get("suggested_solutions", []) or [],
        "category": result.get("category", "general"),
        "keywords": keywords,
        "emojis": list(emojis.keys())
    }

# 📁 CSV feedback analysis
def process_feedback_csv(csv_path: str, feedback_col: str = "Review") -> pd.DataFrame:
    df = pd.read_csv(csv_path)
    if feedback_col not in df.columns:
        raise ValueError(f"Column '{feedback_col}' not found in CSV")

    results = []
    sentiment_counter = Counter()
    emotion_counter = Counter()

    for feedback in df[feedback_col].dropna():
        result = analyze_feedback(str(feedback))
        sentiment_counter[result["sentiment"]] += 1
        emotion_counter[result["emotion"]] += 1

        results.append({
            "Feedback": result["text"],
            "Sentiment": result["sentiment"],
            "Sentiment Confidence (%)": result["sentiment_confidence"],
            "Emotion": result["emotion"],
            "Category": result["category"],
            "Issues": ", ".join(result["issues"]),
            "Solutions": ", ".join(result["suggested_solutions"]),
            "Emojis": ", ".join(result["emojis"]),
            "Keywords": ", ".join(result["keywords"])
        })

    processed_df = pd.DataFrame(results)

    # 📊 Sentiment Percentage Summary
    total = sum(sentiment_counter.values())
    print("\n📊 Sentiment Breakdown:")
    for sentiment in SENTIMENT_CATEGORIES:
        percent = (sentiment_counter[sentiment] / total * 100) if total else 0
        print(f"{sentiment.capitalize()}: {percent:.2f}%")

    # 🎭 Emotion Category Summary
    print("\n🎭 Emotion Breakdown:")
    for emotion in EMOTION_CATEGORIES:
        print(f"{emotion.capitalize()}: {emotion_counter[emotion]}")

    return processed_df
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sivaj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sivaj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = process_feedback_csv("D:/faite/sample_feedbacks.csv", feedback_col="feedback")
# Out:
# 📊 Sentiment Breakdown:
# Positive: 50.00%
# Negative: 50.00%
# Neutral: 0.00%
#
# 🎭 Emotion Breakdown:
# Surprised: 0
# Happy: 5
# Angry: 4
# Fearful: 0
# Disgust: 1
# Sad: 0
# Neutral: 0

# %%
df
# Out:
#                                             Feedback Sentiment  \
# 0  The delivery was late and the packaging was da...  negative
# 1    Excellent customer service! I'm very satisfied.  positive
# 2        Battery life is poor and needs improvement.  negative
# 3  Shipping was fast and the product arrived safely.  positive
# 4      Product quality is terrible, I want a refund.  negative
# 5   Very happy with the quick response from support.  positive
# 6  Item was broken on arrival and support was unh...  negative
# 7    Love the performance of this device. Great job!  positive
# 8         Customer service is slow and unresponsive.  negative
# 9  Really appreciate the fast delivery and qualit...  positive
#
#    Sentiment Confidence (%)  Emotion             Category  \
# 0                       100    angry             delivery
# 1                        95    happy     customer service
# 2                        80  disgust      product quality
# 3                       100    happy             delivery
# 4                        90    angry              quality
# 5                        90    happy              support
# 6                       100    angry              quality
# 7                        95    happy  product performance
# 8                       100    angry     customer service
# 9                        95    happy             delivery
#
#                                               Issues  \
# 0                   late delivery, damaged packaging
# 1
# 2                                  poor battery life
# 3
# 4                                    product quality
# 5
# 6          broken item on arrival, unhelpful support
# 7
# 8  slow customer service, unresponsive customer s...
# 9
#
#                                            Solutions Emojis  \
# 0  Improve delivery timelines, Enhance packaging ...
# 1
# 2                               improve battery life
# 3
# 4                                             refund
# 5
# 6  improve packaging for better protection, enhan...
# 7
# 8  Improve response times, Enhance customer servi...
# 9
#
#                                             Keywords
# 0                 delivery, late, packaging, damaged
# 1            excellent, customer, service, satisfied
# 2            battery, life, poor, needs, improvement
# 3           shipping, fast, product, arrived, safely
# 4           product, quality, terrible, want, refund
# 5                    happy, quick, response, support
# 6          item, broken, arrival, support, unhelpful
# 7              love, performance, device, great, job
# 8              customer, service, slow, unresponsive
# 9  really, appreciate, fast, delivery, quality, p...

# %%
df = process_feedback_csv( "D:/faite/reviews_100_with_date.csv", feedback_col="Review")
# Out:
# 📊 Sentiment Breakdown:
# Positive: 22.00%
# Negative: 59.00%
# Neutral: 19.00%
#
# 🎭 Emotion Breakdown:
# Surprised: 0
# Happy: 22
# Angry: 32
# Fearful: 0
# Disgust: 2
# Sad: 22
# Neutral: 20

# %%
df
# Out:
#                               Feedback Sentiment  Sentiment Confidence (%)  \
# 0               Absolutely love it! 😊💯  positive                       100
# 1            Delivery took too long 🚚👎  negative                        80
# 2      Late delivery and no tracking ⏰  negative                        80
# 3        Too slow and bad experience 😤  negative                        90
# 4     Good quality and fast shipping 🚚  positive                        95
# ..                                 ...       ...                       ...
# 95       Too slow and bad experience 😤  negative                        90
# 96         Battery life is too short 😢  negative                        80
# 97     Late delivery and no tracking ⏰  negative                        80
# 98              Absolutely love it! 😊💯  positive                       100
# 99  Beautiful design but bad battery 🔋   neutral                        50
#
#    Emotion          Category                      Issues  \
# 0    happy           general
# 1    angry          delivery      Delivery took too long
# 2    angry          delivery  Late delivery, No tracking
# 3    angry           service                slow service
# 4    happy          delivery
# ..     ...               ...                         ...
# 95   angry  customer service                slow service
# 96     sad   product quality      Battery life too short
# 97   angry          delivery  Late delivery, No tracking
# 98   happy           general
# 99                   product                 bad battery
#
#                                             Solutions Emojis  \
# 0                                                          😊
# 1                              Improve delivery speed   🚚, 👎
# 2   Improve delivery time estimation, Provide trac...
# 3                            improve speed of service
# 4                                                          🚚
# ..                                                ...    ...
# 95                         Improving speed of service
# 96  Provide better battery life, Offer battery rep...      😢
# 97  Improve delivery time estimation, Provide trac...
# 98                                                         😊
# 99                               improve battery life      🔋
#
#                            Keywords
# 0                  absolutely, love
# 1              delivery, took, long
# 2          late, delivery, tracking
# 3             slow, bad, experience
# 4     good, quality, fast, shipping
# ..                              ...
# 95            slow, bad, experience
# 96             battery, life, short
# 97         late, delivery, tracking
# 98                 absolutely, love
# 99  beautiful, design, bad, battery
#
# [100 rows x 9 columns]

# %%
df1 = process_feedback_csv( "D:/faite/sample_reviews (1).csv", feedback_col="Review")
# Out:
# 📊 Sentiment Breakdown:
# Positive: 26.67%
# Negative: 20.00%
# Neutral: 53.33%
#
# 🎭 Emotion Breakdown:
# Surprised: 1
# Happy: 3
# Angry: 1
# Fearful: 0
# Disgust: 1
# Sad: 1
# Neutral: 7

# %%
df1
# Out:
#                                              Feedback Sentiment  \
# 0   I love this product! 😊 It's amazing and works ...   neutral
# 1          Terrible service. I'm very disappointed. 😡   neutral
# 2        The delivery was late but the item was fine.   neutral
# 3     Fantastic support team! 😍 They helped me a lot.  positive
# 4        Battery drains too fast. Not happy at all. 🔋   neutral
# 5            Excellent packaging and fast delivery. 👍   neutral
# 6   Item was broken on arrival. Very bad experienc...  negative
# 7                Neutral experience. Nothing special.   neutral
# 8   I am fearful about using this again after my l...   neutral
# 9          Product quality is bad. 😢 I want a refund.  negative
# 10             Just okay. Not too great, not too bad.   neutral
# 11           Amazing performance! 😁 Loved it so much.  positive
# 12  Packaging was disgusting. The product was leak...  negative
# 13               I’m surprised how fast it arrived! 😱  positive
# 14          No emojis here but still a great product.  positive
#
#     Sentiment Confidence (%)    Emotion              Category  \
# 0                         50    neutral               general
# 1                         50    neutral               general
# 2                         50                         delivery
# 3                         90      happy               support
# 4                         50    neutral               general
# 5                         50    neutral               general
# 6                         95      angry               quality
# 7                         50    neutral
# 8                         50    neutral               general
# 9                        100        sad               quality
# 10                        50    neutral
# 11                        90      happy           performance
# 12                       100    disgust               quality
# 13                        90  surprised              delivery
# 14                        85      happy  product satisfaction
#
#                         Issues  \
# 0                  unspecified
# 1                  unspecified
# 2                late delivery
# 3
# 4                  unspecified
# 5                  unspecified
# 6                  broken item
# 7
# 8                  unspecified
# 9              product quality
# 10
# 11
# 12  packaging, product leakage
# 13
# 14
#
#                                             Solutions Emojis  \
# 0                                       review needed      😊
# 1                                       review needed      😡
# 2                   improved delivery time estimation
# 3                                                          😍
# 4                                       review needed      🔋
# 5                                       review needed      👍
# 6   Provide a replacement item immediately, Improv...      👎
# 7
# 8                                       review needed
# 9                                              refund      😢
# 10
# 11                                                         😁
# 12         improve packaging quality, prevent leakage
# 13                                                         😱
# 14
#
#                                     Keywords
# 0   love, product, amazing, works, perfectly
# 1            terrible, service, disappointed
# 2                 delivery, late, item, fine
# 3      fantastic, support, team, helped, lot
# 4               battery, drains, fast, happy
# 5       excellent, packaging, fast, delivery
# 6     item, broken, arrival, bad, experience
# 7      neutral, experience, nothing, special
# 8           fearful, using, last, experience
# 9        product, quality, bad, want, refund
# 10                          okay, great, bad
# 11         amazing, performance, loved, much
# 12   packaging, disgusting, product, leaking
# 13                  surprised, fast, arrived
# 14             emojis, still, great, product
